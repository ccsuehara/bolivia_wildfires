# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
import statsmodels.api as sm

# %%
import eda_analysis as ea
import plotting_libs as plo
import ts_tests as tse

import pandas as pd
import altair as alt

# %%
# %matplotlib inline

# %%
wf_data = "/Users/ccsuehara/Google Drive/Bolivia Wildfires/Bolivia Fire Historical Raw Data"
eco_act = "/Users/ccsuehara/GH folders/Bolivia_wildfires/data"

# %%
## Have data ready
bolivia_dptos = ea.bol_gdf() ##geodata from Bolivia 
econ_act = ea.prepare_econ_data(eco_act) ## economic activities from Bolivia

# %%
wildfires = ea.prepare_wildfires_data(wf_data)
wildfires = ea.keep_dep_confid(wildfires, 50)
wildfires = ea.make_cutpoints_frp(wildfires, 40)
small_fire, big_fire = ea.group_wf(wildfires)

# %%
## Obtain monthly data
monthly_big = ea.group_data(big_fire,
                            ['year_month', 'year', 'month'],
                           {'num_fires': 'sum',
                            'frp': ['mean', 'median', 'max']})

# %%
monthly_small = ea.group_data(small_fire,
                            ['year_month', 'year', 'month'],
                           {'num_fires': 'sum',
                            'frp': ['mean', 'median', 'max']})

monthly_small.rename(columns = {'num_firessum': 's_num_firessum',
                               'frpmean': 's_frpmean',
                               'frpmedian': 's_frpmedian',
                               'frpmax': 's_frpmax'}, inplace = True)

# %%
monthly_wf = pd.merge(monthly_big, monthly_small, on = ["year_month", "year", "month"])

# %%
eda_df = pd.merge(econ_act, monthly_wf, on = ["year_month", "year", "month"])
eda_df.drop(columns = ['year', 'month', 'month_num', 'year_month'], inplace = True)
eda_df = eda_df.set_index('date')

# %%
g1 = plo.small_mults(eda_df.reset_index(),
               ['ind', 'ag', 'energy', 'mining'])
g2 = plo.small_mults(eda_df.reset_index(),
               ['manufacturing', 'utilities','construction', 'commerce'])
g3 = plo.small_mults(eda_df.reset_index(),
               ['transportation', 'communications','finance', 'professional_services']) 
g4 = plo.small_mults(eda_df.reset_index(),
               ['public_services', 'other_services'])

# %%
g1 | g2 | g3 | g4
# Out:
# alt.HConcatChart(...)

# %%
g1 = plo.small_mults(eda_df.reset_index(),
               ['num_firessum', 'frpmean'])
g2 = plo.small_mults(eda_df.reset_index(),
               ['frpmedian', 'frpmax'])
g3 = plo.small_mults(eda_df.reset_index(),
               ['s_num_firessum', 's_frpmean'])
g4 = plo.small_mults(eda_df.reset_index(),
               ['s_frpmedian', 's_frpmax'])

# %%
g1 | g2 | g3 | g4
# Out:
# alt.HConcatChart(...)

# %%
dfcorr = ea.transf_4_heat(eda_df)
plo.pearson_heatmap(dfcorr)
# Out:
# alt.LayerChart(...)

# %%
tse.print_results_adf(eda_df, tse.aug_df)
# Out:
#     Augmented Dickey-Fuller Test
#  -------------------------------------------------------
# ind | -0.3371 | 13 | 13 | 0.9201 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# ag | 3.4301 | 12 | 12 | 1.0 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# energy | -1.5838 | 12 | 12 | 0.4917 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# mining | -1.3814 | 11 | 11 | 0.5912 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# manufacturing | 1.6075 | 12 | 12 | 0.9979 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# utilities | -1.2853 | 12 | 12 | 0.6359 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# construction | -1.3839 | 13 | 13 | 0.59 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# commerce | 1.8936 | 12 | 12 | 0.9985 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# transportation | -1.3775 | 13 | 13 | 0.593 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# communications | 3.9224 | 13 | 13 | 1.0 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# finance | 0.6254 | 13 | 13 | 0.9882 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# professional_services | 4.2833 | 12 | 12 | 1.0 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# public_services | 0.6459 | 13 | 13 | 0.9887 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# other_services | 3.8307 | 13 | 13 | 1.0 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# num_firessum | -2.2019 | 11 | 11 | 0.2056 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# frpmean | -3.7106 | 8 | 8 | 0.004 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# frpmedian | -6.8631 | 6 | 6 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# frpmax | -5.8502 | 5 | 5 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# s_num_firessum | -2.1471 | 11 | 11 | 0.226 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# s_frpmean | -2.8468 | 11 | 11 | 0.0519 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# s_frpmedian | -3.0141 | 13 | 13 | 0.0336 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# s_frpmax | -9.3007 | 0 | 0 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------

# %%
#Making logs so to see if if stationarizes
log_eda_df = ea.log_df(eda_df)

# %%
g1 = plo.small_mults(log_eda_df.reset_index(),
               ['ind', 'ag', 'energy', 'mining'])
g2 = plo.small_mults(log_eda_df.reset_index(),
               ['manufacturing', 'utilities','construction', 'commerce'])
g3 = plo.small_mults(log_eda_df.reset_index(),
               ['transportation', 'communications','finance', 'professional_services']) 
g4 = plo.small_mults(log_eda_df.reset_index(),
               ['public_services', 'other_services']) 
g1 | g2 | g3 | g4
# Out:
# alt.HConcatChart(...)

# %%
tse.print_results_adf(log_eda_df, tse.aug_df)
# Out:
#     Augmented Dickey-Fuller Test
#  -------------------------------------------------------
# ind | -1.477 | 13 | 13 | 0.5449 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# ag | 1.8029 | 14 | 14 | 0.9984 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# energy | -1.9335 | 14 | 14 | 0.3165 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# mining | -1.4692 | 11 | 11 | 0.5487 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# manufacturing | -0.1494 | 12 | 12 | 0.9443 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# utilities | -3.5924 | 12 | 12 | 0.0059 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# construction | -3.0999 | 13 | 13 | 0.0266 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# commerce | -0.0752 | 12 | 12 | 0.9519 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# transportation | -2.7907 | 12 | 12 | 0.0596 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# communications | 2.7522 | 13 | 13 | 1.0 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# finance | -0.767 | 13 | 13 | 0.8286 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# professional_services | 1.931 | 12 | 12 | 0.9986 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# public_services | -0.5723 | 13 | 13 | 0.8771 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# other_services | 3.0717 | 13 | 13 | 1.0 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# num_firessum | -1.8878 | 12 | 12 | 0.3378 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# frpmean | -3.7168 | 8 | 8 | 0.0039 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# frpmedian | -6.9462 | 6 | 6 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# frpmax | -1.9986 | 13 | 13 | 0.2872 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# s_num_firessum | -1.7638 | 12 | 12 | 0.3986 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# s_frpmean | -2.927 | 11 | 11 | 0.0423 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# s_frpmedian | -8.8138 | 6 | 6 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# s_frpmax | -9.414 | 0 | 0 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------

# %%
#Making logs so to see if if stationarizes
log_diff_eda_df = ea.difference_df(log_eda_df)

# %%
g1 = plo.small_mults(log_diff_eda_df.reset_index(),
               ['ind', 'ag', 'energy', 'mining'])
g2 = plo.small_mults(log_diff_eda_df.reset_index(),
               ['manufacturing', 'utilities','construction', 'commerce'])
g3 = plo.small_mults(log_diff_eda_df.reset_index(),
               ['transportation', 'communications','finance', 'professional_services']) 
g4 = plo.small_mults(log_diff_eda_df.reset_index(),
               ['public_services', 'other_services']) 
g1 | g2 | g3 | g4
# Out:
# alt.HConcatChart(...)

# %%
tse.print_results_adf(log_diff_eda_df, tse.aug_df)
# Out:
#     Augmented Dickey-Fuller Test
#  -------------------------------------------------------
# ind | -1.4134 | 6 | 6 | 0.5758 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# ag | -2.4675 | 3 | 3 | 0.1236 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# energy | -2.6278 | 12 | 12 | 0.0874 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# mining | -4.0109 | 11 | 11 | 0.0014 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# manufacturing | -5.551 | 1 | 1 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# utilities | -0.6015 | 8 | 8 | 0.8706 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# construction | -0.6782 | 13 | 13 | 0.8523 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# commerce | -6.1133 | 0 | 0 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# transportation | -3.6501 | 1 | 1 | 0.0049 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# communications | -2.4541 | 4 | 4 | 0.127 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# finance | -2.7565 | 4 | 4 | 0.0648 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# professional_services | -6.233 | 0 | 0 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# public_services | -2.7433 | 3 | 3 | 0.0668 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# other_services | -3.1486 | 2 | 2 | 0.0232 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# num_firessum | -2.4169 | 13 | 13 | 0.137 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# frpmean | -3.2961 | 13 | 13 | 0.0151 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# frpmedian | -5.8806 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# frpmax | -2.7789 | 13 | 13 | 0.0613 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# s_num_firessum | -2.3269 | 13 | 13 | 0.1634 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# s_frpmean | -6.2052 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# s_frpmedian | -6.4731 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# s_frpmax | -5.9445 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------

# %%
log_diff2_eda_df = ea.difference_df(log_diff_eda_df)

# %%
g1 = plo.small_mults(log_diff2_eda_df.reset_index(),
               ['ind', 'ag', 'energy', 'mining'])
g2 = plo.small_mults(log_diff2_eda_df.reset_index(),
               ['manufacturing', 'utilities','construction', 'commerce'])
g3 = plo.small_mults(log_diff2_eda_df.reset_index(),
               ['transportation', 'communications','finance', 'professional_services']) 
g4 = plo.small_mults(log_diff2_eda_df.reset_index(),
               ['public_services', 'other_services']) 
g1 | g2 | g3 | g4
# Out:
# alt.HConcatChart(...)

# %%
tse.print_results_adf(log_diff2_eda_df, tse.aug_df)
# Out:
#     Augmented Dickey-Fuller Test
#  -------------------------------------------------------
# ind | -2.7351 | 13 | 13 | 0.0682 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# ag | -3.4749 | 12 | 12 | 0.0087 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# energy | -4.4842 | 13 | 13 | 0.0002 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# mining | -6.1272 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# manufacturing | -3.822 | 12 | 12 | 0.0027 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# utilities | -2.7883 | 12 | 12 | 0.06 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# construction | -3.0318 | 13 | 13 | 0.032 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# commerce | -5.8774 | 0 | 0 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# transportation | -5.4509 | 0 | 0 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# communications | -4.4034 | 1 | 1 | 0.0003 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# finance | -2.0547 | 13 | 13 | 0.2631 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# professional_services | -1.9678 | 12 | 12 | 0.3009 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# public_services | -3.4141 | 13 | 13 | 0.0105 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# other_services | -4.3486 | 11 | 11 | 0.0004 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# num_firessum | -2.45 | 13 | 13 | 0.1281 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# frpmean | -3.1574 | 13 | 13 | 0.0226 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# frpmedian | -7.2785 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# frpmax | -2.5252 | 13 | 13 | 0.1095 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# s_num_firessum | -2.353 | 13 | 13 | 0.1554 | Can't reject H0: Non-Stationary
#  -------------------------------------------------------
#
#
# s_frpmean | -7.983 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# s_frpmedian | -7.9223 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------
#
#
# s_frpmax | -8.323 | 11 | 11 | 0.0 | Reject H0: Stationary
#  -------------------------------------------------------

# %%
Y_array = ['ind', 'ag', 'energy', 'mining', 'manufacturing', 'utilities',
       'construction', 'commerce', 'transportation', 'communications',
       'finance', 'professional_services', 'public_services', 'other_services',]

X_array = ['num_firessum', 'frpmean', 'frpmedian', 'frpmax', 's_num_firessum',
       's_frpmean', 's_frpmedian', 's_frpmax']


df_of_betas = ea.make_betas_matrix(log_diff2_eda_df,X_array, Y_array)

# %%
df_of_betas
# Out:
#             index     coeff     pvals  conf_lower  conf_higher  \
# 1    num_firessum -0.000090  0.933397   -0.002212     0.002032
# 1         frpmean  0.007268  0.081976   -0.000936     0.015472
# 1       frpmedian  0.022594  0.001519    0.008814     0.036375
# 1          frpmax  0.000973  0.426417   -0.001442     0.003388
# 1  s_num_firessum -0.000777  0.573219   -0.003503     0.001948
# 1       s_frpmean  0.004078  0.781735   -0.025000     0.033155
# 1     s_frpmedian  0.012334  0.200771   -0.006651     0.031318
# 1        s_frpmax -0.091971  0.125788   -0.210095     0.026152
# 1    num_firessum -0.005926  0.001077   -0.009426    -0.002426
# 1         frpmean -0.001807  0.803426   -0.016151     0.012537
# 1       frpmedian  0.002857  0.820100   -0.021968     0.027683
# 1          frpmax -0.000729  0.730291   -0.004907     0.003449
# 1  s_num_firessum -0.008438  0.000274   -0.012891    -0.003984
# 1       s_frpmean -0.062025  0.013415   -0.110953    -0.013097
# 1     s_frpmedian -0.037971  0.021501   -0.070241    -0.005700
# 1        s_frpmax -0.245181  0.017283   -0.446249    -0.044112
# 1    num_firessum  0.017414  0.090625   -0.002799     0.037626
# 1         frpmean  0.106980  0.007397    0.029253     0.184706
# 1       frpmedian  0.187668  0.006606    0.053266     0.322070
# 1          frpmax  0.022210  0.058209   -0.000784     0.045203
# 1  s_num_firessum  0.015257  0.250602   -0.010911     0.041424
# 1       s_frpmean  0.239348  0.089763   -0.037716     0.516411
# 1     s_frpmedian  0.152758  0.099555   -0.029464     0.334981
# 1        s_frpmax -0.078284  0.893028   -1.228626     1.072057
# 1    num_firessum -0.014993  0.117750   -0.033834     0.003848
# 1         frpmean -0.016440  0.662948   -0.090946     0.058067
# 1       frpmedian  0.071506  0.272313   -0.056884     0.199896
# 1          frpmax -0.010925  0.319345   -0.032559     0.010709
# 1  s_num_firessum -0.024357  0.047465   -0.048438    -0.000277
# 1       s_frpmean  0.166557  0.205727   -0.092657     0.425771
# 1     s_frpmedian  0.222743  0.009235    0.056091     0.389395
# 1        s_frpmax -0.609599  0.259170   -1.674297     0.455099
# 1    num_firessum -0.000875  0.639623   -0.004567     0.002817
# 1         frpmean -0.004454  0.542810   -0.018906     0.009998
# 1       frpmedian  0.003502  0.782342   -0.021541     0.028544
# 1          frpmax -0.001779  0.403846   -0.005984     0.002426
# 1  s_num_firessum -0.000677  0.778257   -0.005429     0.004074
# 1       s_frpmean -0.036638  0.151186   -0.086857     0.013581
# 1     s_frpmedian -0.014339  0.394053   -0.047532     0.018855
# 1        s_frpmax -0.000929  0.992951   -0.208727     0.206869
# 1    num_firessum  0.001853  0.204286   -0.001022     0.004727
# 1         frpmean  0.014876  0.008499    0.003869     0.025882
# 1       frpmedian  0.026379  0.006966    0.007360     0.045398
# 1          frpmax  0.002418  0.146158   -0.000855     0.005691
# 1  s_num_firessum  0.001278  0.497114   -0.002437     0.004993
# 1       s_frpmean  0.007013  0.726806   -0.032641     0.046666
# 1     s_frpmedian  0.006812  0.605476   -0.019233     0.032857
# 1        s_frpmax  0.032297  0.694818   -0.130327     0.194921
# 1    num_firessum  0.008725  0.002162    0.003215     0.014234
# 1         frpmean  0.020971  0.063064   -0.001160     0.043103
# 1       frpmedian  0.024640  0.208789   -0.013969     0.063250
# 1          frpmax  0.003602  0.275440   -0.002908     0.010113
# 1  s_num_firessum  0.009584  0.009185    0.002419     0.016750
# 1       s_frpmean  0.095204  0.015383    0.018535     0.171873
# 1     s_frpmedian  0.064349  0.012635    0.014034     0.114663
# 1        s_frpmax  0.135454  0.405756   -0.186028     0.456936
# 1    num_firessum -0.001523  0.074383   -0.003199     0.000152
# 1         frpmean -0.006526  0.050666   -0.013071     0.000019
# 1       frpmedian -0.003896  0.503284   -0.015387     0.007595
# 1          frpmax -0.001017  0.298754   -0.002946     0.000912
# 1  s_num_firessum -0.001697  0.122963   -0.003859     0.000466
# 1       s_frpmean -0.016688  0.154889   -0.039772     0.006395
# 1     s_frpmedian -0.009481  0.219323   -0.024686     0.005723
# 1        s_frpmax -0.029320  0.543745   -0.124669     0.066030
# 1    num_firessum  0.001240  0.581125   -0.003197     0.005676
# 1         frpmean  0.001914  0.827875   -0.015481     0.019310
# 1       frpmedian  0.012548  0.409568   -0.017477     0.042572
# 1          frpmax  0.000399  0.876367   -0.004670     0.005468
# 1  s_num_firessum  0.002956  0.305504   -0.002732     0.008644
# 1       s_frpmean -0.018049  0.557807   -0.078856     0.042759
# 1     s_frpmedian  0.006642  0.742891   -0.033362     0.046647
# 1        s_frpmax -0.084649  0.502649   -0.333950     0.164652
# 1    num_firessum -0.000094  0.858164   -0.001132     0.000944
# 1         frpmean -0.002741  0.181044   -0.006776     0.001293
# 1       frpmedian -0.006899  0.050748   -0.013821     0.000023
# 1          frpmax -0.000479  0.424034   -0.001660     0.000703
# 1  s_num_firessum  0.000432  0.521980   -0.000900     0.001765
# 1       s_frpmean -0.012065  0.091843   -0.026122     0.001992
# 1     s_frpmedian -0.007523  0.109954   -0.016773     0.001727
# 1        s_frpmax -0.007854  0.790247   -0.066197     0.050488
# 1    num_firessum  0.002711  0.134004   -0.000847     0.006268
# 1         frpmean -0.006269  0.377767   -0.020290     0.007753
# 1       frpmedian -0.015514  0.206412   -0.039696     0.008668
# 1          frpmax  0.001054  0.611101   -0.003040     0.005148
# 1  s_num_firessum  0.004009  0.084376   -0.000552     0.008571
# 1       s_frpmean  0.014461  0.561388   -0.034707     0.063629
# 1     s_frpmedian -0.002860  0.861363   -0.035216     0.029497
# 1        s_frpmax  0.247167  0.014311    0.050297     0.444036
# 1    num_firessum -0.000480  0.446293   -0.001724     0.000764
# 1         frpmean -0.004708  0.054862   -0.009516     0.000100
# 1       frpmedian -0.005780  0.174923   -0.014167     0.002607
# 1          frpmax -0.000629  0.381889   -0.002047     0.000790
# 1  s_num_firessum -0.000332  0.682330   -0.001935     0.001271
# 1       s_frpmean -0.011532  0.180853   -0.028496     0.005433
# 1     s_frpmedian -0.007241  0.201230   -0.018398     0.003916
# 1        s_frpmax  0.049113  0.164573   -0.020429     0.118655
# 1    num_firessum -0.006908  0.000521   -0.010742    -0.003074
# 1         frpmean -0.014100  0.075952   -0.029695     0.001495
# 1       frpmedian -0.028012  0.041185   -0.054885    -0.001140
# 1          frpmax -0.002921  0.208534   -0.007495     0.001653
# 1  s_num_firessum -0.006877  0.007863   -0.011914    -0.001841
# 1       s_frpmean -0.113187  0.000027   -0.164514    -0.061861
# 1     s_frpmedian -0.067646  0.000151   -0.101848    -0.033444
# 1        s_frpmax -0.233689  0.040025   -0.456554    -0.010823
# 1    num_firessum -0.000148  0.751897   -0.001074     0.000778
# 1         frpmean -0.004235  0.019653   -0.007781    -0.000689
# 1       frpmedian -0.005059  0.109540   -0.011271     0.001154
# 1          frpmax -0.000356  0.505411   -0.001411     0.000699
# 1  s_num_firessum -0.000082  0.891298   -0.001274     0.001109
# 1       s_frpmean  0.000222  0.972415   -0.012480     0.012924
# 1     s_frpmedian -0.001350  0.749230   -0.009695     0.006994
# 1        s_frpmax  0.073880  0.004361    0.023552     0.124209
#
#                   depend
# 1                    ind
# 1                    ind
# 1                    ind
# 1                    ind
# 1                    ind
# 1                    ind
# 1                    ind
# 1                    ind
# 1                     ag
# 1                     ag
# 1                     ag
# 1                     ag
# 1                     ag
# 1                     ag
# 1                     ag
# 1                     ag
# 1                 energy
# 1                 energy
# 1                 energy
# 1                 energy
# 1                 energy
# 1                 energy
# 1                 energy
# 1                 energy
# 1                 mining
# 1                 mining
# 1                 mining
# 1                 mining
# 1                 mining
# 1                 mining
# 1                 mining
# 1                 mining
# 1          manufacturing
# 1          manufacturing
# 1          manufacturing
# 1          manufacturing
# 1          manufacturing
# 1          manufacturing
# 1          manufacturing
# 1          manufacturing
# 1              utilities
# 1              utilities
# 1              utilities
# 1              utilities
# 1              utilities
# 1              utilities
# 1              utilities
# 1              utilities
# 1           construction
# 1           construction
# 1           construction
# 1           construction
# 1           construction
# 1           construction
# 1           construction
# 1           construction
# 1               commerce
# 1               commerce
# 1               commerce
# 1               commerce
# 1               commerce
# 1               commerce
# 1               commerce
# 1               commerce
# 1         transportation
# 1         transportation
# 1         transportation
# 1         transportation
# 1         transportation
# 1         transportation
# 1         transportation
# 1         transportation
# 1         communications
# 1         communications
# 1         communications
# 1         communications
# 1         communications
# 1         communications
# 1         communications
# 1         communications
# 1                finance
# 1                finance
# 1                finance
# 1                finance
# 1                finance
# 1                finance
# 1                finance
# 1                finance
# 1  professional_services
# 1  professional_services
# 1  professional_services
# 1  professional_services
# 1  professional_services
# 1  professional_services
# 1  professional_services
# 1  professional_services
# 1        public_services
# 1        public_services
# 1        public_services
# 1        public_services
# 1        public_services
# 1        public_services
# 1        public_services
# 1        public_services
# 1         other_services
# 1         other_services
# 1         other_services
# 1         other_services
# 1         other_services
# 1         other_services
# 1         other_services
# 1         other_services
